# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # load data

# %%
data = pd.read_csv("ipl.csv")

# %%
data.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
data.head(7)
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  4/9/2017                Gujarat Lions
# 6   7    2017     Mumbai  4/9/2017        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# ...

# %%
data.tail(5)
# Out:
#       id  season       city       date                team1  \
# 631  632    2016     Raipur  5/22/2016     Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016        Gujarat Lions
# 633  634    2016      Delhi  5/25/2016  Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016        Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data['player_of_match']
# Out:
# 0        Yuvraj Singh
# 1           SPD Smith
# 2             CA Lynn
# 3          GJ Maxwell
# 4           KM Jadhav
#             ...
# 631           V Kohli
# 632    AB de Villiers
# 633      MC Henriques
# 634         DA Warner
# 635       BCJ Cutting
# Name: player_of_match, Length: 636, dtype: object

# %%
data['player_of_match'].value_counts(-5)
# Out:
# CH Gayle          0.028436
# YK Pathan         0.025276
# AB de Villiers    0.023697
# DA Warner         0.023697
# RG Sharma         0.022117
#                     ...
# BA Bhatt          0.001580
# MS Bisla          0.001580
# KS Williamson     0.001580
# LH Ferguson       0.001580
# TA Boult          0.001580
# Name: player_of_match, Length: 201, dtype: float64

# %%
data['player_of_match'].value_counts(5)
# Out:
# CH Gayle          0.028436
# YK Pathan         0.025276
# AB de Villiers    0.023697
# DA Warner         0.023697
# RG Sharma         0.022117
#                     ...
# BA Bhatt          0.001580
# MS Bisla          0.001580
# KS Williamson     0.001580
# LH Ferguson       0.001580
# TA Boult          0.001580
# Name: player_of_match, Length: 201, dtype: float64

# %%
plt.figure(figsize=(15,5))
plt.bar(list(data['player_of_match'].value_counts().keys()),list(data['player_of_match'].value_counts()))
plt.show()
